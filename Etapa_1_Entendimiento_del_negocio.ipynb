# %% [markdown]
# **Parcial 1 - Enendimiento de la organización**
#
# En este trabajo se busca definir el contexto inicial para un proyecto de analítica de datos.
#
#
# **Consideraciones**
#
# * Lea estas consideraciones!!!
# * Solo modifique las celdas que le son indicadas.
# * Asegurese de incluir la documentación (**Con ortografía**, si no quieren perder puntos) para cada una de las fucniones construídas.

# %% [markdown]
# # VALIDACIÓN DE CERTIFICADOS DE DEFUNCIÓN DE NACIMIENTOS EN COLOMBIA

# %% [markdown]
# **Datos de la presentación**
# # --------------------- ojo!!!!!!!----------------------------
#
# * **Curso**: 901N
#
# * **Autores**:
#
# 1. Andres Felipe Arevalo Moreno
# 2. Luis Alexander Pedraza Cuellar
#
# # --------------------- ojo!!!!!!!----------------------------

# %% [markdown]
# # Fase 1: Entendimiento del negocio

# %% [markdown]
# ## La organización (1.3)

# %% [markdown]
# ### Glosario de términos (0.3)

# %% [markdown]
# **Especificidad**: se refiere a la probabilidad de que los resultados de una prueba sean negativos si realmente no tiene la enfermedad. La especificidad nos permite saber qué probabilidad hay de que la prueba dé resultado negativo para alguien que no tiene la característica.

# %% [markdown]
# **Certificado de Defunción**: Es un documento legal emitido por un médico que indica cuándo murió una persona, o un documento emitido por una oficina de registro civil del gobierno, que declara la fecha, el lugar y la causa de la muerte de una persona, según lo ingresado en un registro oficial. de muertes.

# %% [markdown]
# **Análisis de regresión**: El análisis de la regresión es un proceso estadístico para estimar las relaciones entre variables. Incluye muchas técnicas para el modelado y análisis de diversas variables, cuando la atención se centra en la relación entre una variable dependiente y una o más variables independientes.

# %% [markdown]
# * *Seguir pensando cual otros podrían ser de interés*

# %% [markdown]
# ### Objetivo  y contexto organizacional (0.4)
#
# Describa la razón de ser de la organización para la cual se desarrolla el proyecto.

# %% [markdown]
# Policía Nacional de Colombia.
#
# “El fin primordial de la Policía Nacional es el mantenimiento de la convivencia como condición necesaria, para el ejercicio de los derechos y libertades públicas y para asegurar que los habitantes de Colombia convivan en paz fundamentada en el código de ética policial”.

# %% [markdown]
# * *Ampliar un poco en el sentido del proyecto, por ejemplo indicando que una de sus preocupaciones es la desaparición o robo de bebés...*

# %% [markdown]
# ### Estado actual de la organización (0.6)

# %% [markdown]
# **Problema actual**:
#
# Describa la situación actual, en relación con el problema por resolver. Atendiendo, además, a la siguiente pregunta: ¿cuál es el conocimiento previo disponible acerca del problema?
#
# Indique también, cual es el área que se verá impactada con el desarrollo del proyecto y el impacto esperado.

# %% [markdown]
# En la actualidad en las clínicas y hospitales de Colombia se generan muchos nacimientos al día, pero hay ocasiones en las cuales esos nacimientos no terminan de buena manera, ya que se presenta defunciones de los bebes en el parto, más sin embargo se han instaurado muchas quejas por parte de los padres, puesto que estos afirman que sus hijos nacían vivos en el parto pero posteriormente los médicos o el personal a cargo les notificaban que sus hijos habían fallecidos por causas que no son muy creíbles.
#
# Es por esta problemática, que recaen las denuncias de estos padres indignados en la policía nacional, buscado una solución al tema. pero la policía se ve limitada ante el tema puesto que no tienen una forma veraz de afirmar que los bebes estén vivos, o de verificar que los certificados de defunción son válidos.
#
# Además, es de acotar que según estadísticas del DANE hay un aumento en certificados de defunciones fetales del 8 % a nivel nacional, para lo cual la policía nacional termina de convencerse de que no es normal este aumento. y quieren detectar la validez de los certificados de defunción. con la finalidad de confirmar una hipótesis que tienen, y es la probabilidad que algunas instituciones estén raptando bebes con diferentes fines.
#
#
# Por anteriores razones, el desarrollo de este proyecto se verá reflejado en el área de la salud más directamente al seguimiento y control de los procesos y verificación de nacimientos en los hospitales, clínicas o demás instituciones de la salud. Además, de reforzar la seguridad social en las familias colombianas detectando que sus hijos no sean raptados por personas inescrupulosas en los momentos de parto.

# %% [markdown]
# **Solución actual**:
#
# En caso de existir alguna solución o sistema que en la actualidad atienda esa problemática de forma total o parcial, describa las características de la solución indicando sus ventajas y desventajas.

# %% [markdown]
# A partir de la problemática anteriormente mencionada, se proyecta una solución al tema y es **generar un modelo de validación de certificados de defunción de nacimientos en Colombia.**
#
# Como características principales de la solución se precisa disponer de tecnologías de análisis de datos, análisis de regresión en conjuntos de datos de nacimientos y defunciones en recién nacidos de Colombia. y así, obtener un modelo de veracidad de certificados de defunciones, el cual se dispondrá a la policía nacional, organización para la cual se desarrolla el proyecto, en donde finalmente, se espera que ellos le den el uso necesario para salvaguardar la vida de los recién nacidos y tal vez gestionar sistemas de verificación en las instituciones de salud.

# %% [markdown]
# * *Esto parece más algo a futuro que una solución actual. Una solución actual podría ser que tienen expertos revisando actas médicas de forma aleatoria, o que la policia asiste a los nacimientos...*

# %% [markdown]
# ## Valoración de la situación (0.8)

# %% [markdown]
# ### Recursos de Datos (0.8)
#
# Responda a las siguientes preguntas:

# %% [markdown]
# **¿Qué orígenes de datos están disponibles?, al menos 2** (0.5):
#
# Poner la url de la fuente y describa que información contiene cada uno.

# %% [markdown]
# URL DE LA FUENTE: https://microdatos.dane.gov.co/index.php/catalog/652/get_microdata
#
# En esta fuente se encuetra las defunciones y nacimientos de años recientes en colombia, para este proyecto se usan dos data sets del año 2018 que son los mas recientes.
#
#
#
# *   El primer dataset muestra las estadísticas de nacimientos que se producen a partir de la información proveniente de los certificados de nacido vivo de colombia.
# *   El segundo dataset muestra las estadísticas de defunciones fetales que se producen a partir de la información proveniente de los certificados de defunción en colombia.

# %% [markdown]
# **¿Cómo se almacenan los datos?** (0.3):
#
# Formato y almacenamiento: en un archivo csv, en una db sql, etc. En caso de ser necesario indicar credenciales o filtros necesarios para su consulta.

# %% [markdown]
# El almacenamiento de los datos está en dos archivos csv.

# %% [markdown]
# **¿Existen restricciones de seguridad que impidan o limiten el acceso a los datos necesarios?**:

# %% [markdown]
# No hay restricción para acceder a los datos, son de carácter público.

# %% [markdown]
# **¿Ha planificado adquirir datos externos, como información demográfica?**:

# %% [markdown]
# si. se planea traer informacion estadistica de indices de mortalidad en nacimientos en los ultimos años.

# %% [markdown]
# ## Determinación de los objetivos del proyecto (2.5)

# %% [markdown]
# ### Objetivo del proyecto (1.25)
#
# Plantear brevemente que necesidad se desea atender o que problema se busca resolver, por ejemplo:
#
# *	Detectar el fraude en el uso de tarjetas de crédito de la organización credicerdi
# *	Clasificar alumnos según la probabilidad de terminar la carrera en diferentes cantidades de semestres
# *	Predecir posibles siniestros en cultivos de maíz de la región occidente

# %% [markdown]
# Detectar la falsedad de certificados de defunción de recién nacidos robados en las instituciones de salud en Colombia.

# %% [markdown]
# 👌

# %% [markdown]
# ### Criterio de éxito (1.25)
#
# A partir del problema especificar como se podrá medir si el proyecto tiene el éxito esperado, por ejemplo:
# *	Identificar el 95% de los casos de fraude en el dataset de prueba.
# *	Identificación del 95% de los alumnos que terminaran la carrera en 9 semestres, dentro del dataset de prueba.
# *	Obtener una predicción del 99% de los eventos de siniestros en el dataset de prueba.

# %% [markdown]
# Identificar el 90% de especificidad en certificados de defunción de bebes robados en el dataset de prueba.

# %% [markdown]
# * *¿qué significaría: bebes y mamas gratis?*
# * *¿Cómo saben que los bebés fueron robados?*
# * *Otra opción podría ser, identificar el 90% de los certificados que fueron incorrectamente catalogados como fallecido. Aunque, para esto se tendría que saber cuales fueron incorrectamente catalogados*
# * *Otra forma de verlo es identificar con un 90% espeficidad cuando según las caracteristicas de un nacimiento debe ser catalogado como vivo.*

# %% [markdown]
# ## Producción de un plan de proyecto (0.4)
#
# ---

# %% [markdown]
# Diligencie la siguiente tabla:
#
# | Fase | Tiempo (semanas) | Recursos|Riesgos|
# | --- | --- | --- | ----------- |
# | Comprensión del negocio | 2 | Fuentes de datos abiertos extraidos de datos abiertos de colombia. | Que no se encuentre informacion de valor o incompleta para comprender el negocio. |
# | Comprensión de los datos | 3 | Pdf de documentacion de los 2 dataset. Ayuda apara comprender el contexto de los datos, como la descripcion de las columnas y su contenido.| Escojer mal la columnas del dataset para su posterior analisis. |
# | Preparación de los datos | 3| Un equipo en fisico con raizen 5 con visual studio, Ram de 16 gb, SSD de 512 gb. Un equipo con maquina virtual que trabaja con google colab.| Daño o perdida en uno de los equipos.  |
# | Modelado | 5 | Google Colab, visual studio, Una funcion de aprendizaje, librerias para diagramas o graficas. | Que se detenga o se pierda el apremdizaje en el equipo. |
# | Evaluación | 2 | Resultados previos de todos los procedimientos anteriores.   | No cumplir con los objetivos de deteccion de exito en el proyecto.|
# | Despliegue | 1 | Ambiente de despligue (Servidor o cumputador) |  Afectaciones en el funcionamiento o compilamiento del sistema. |

# %% [markdown]
# ## Auto valoración

# %% [markdown]
# **¿Está todo listo para el siguiente paso?**
#
# Responda a las siguientes preguntas. Es una auto valoración de lo realizado. En caso de que alguna no pueda ser respondida debería devolverse al punto correspondiente e identificar las carencias.
#
# *	¿Qué espera obtener de este proyecto?
# *	¿Dispone de los recursos necesarios para completar los objetivos?
# *	¿Dispone de acceso a todos los datos necesarios para el proyecto?
